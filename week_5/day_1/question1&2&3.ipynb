# %%
#       data analysis is a process of inspecting, cleansing, transforming, and modeling data with the goal
# of discovering useful information, informing conclusions, and supporting decision-making. data analysis is
# important drives informed Decision-Making, helps identify problems and opportunities and imporives efficiency.
# Data analysis is used healthcare which involves analyzing vast datasets from electronic health records, medical
# imaging, genomic sequencing, and wearable devices.moreover the retail sector uses data analysis to understand
# consumer behavior at an unprecedented level of detail.Cities are using data analysis to become more efficient,
# sustainable, and livable. By collecting data from sensors, GPS devices, cameras, and citizen interactions, city
# planners can optimize the use of resources and improve public services.

import pandas as pd
df=pd.read_csv("/content/Time Americans Spend Sleeping.csv")
df.head(7)
#it shows the average hours of sleep for different age groups
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
# 5      5  2008  Annual                      8.60           0.023     All days
# 6      6  2009  Annual                      8.67           0.023     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both
# 5  15 years and over  Sleeping  Both
# 6  15 years and over  Sleeping  Both

# %%
mh=pd.read_csv("/content/Mental health Depression disorder Data.csv")
mh.head(7)
#this dataset shows the percentage of mental health diseases for different entity
# Out:
# /tmp/ipython-input-4088608360.py:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   mh=pd.read_csv("/content/Mental health Depression disorder Data.csv")
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
# 5      5  Afghanistan  AFG  1995          0.160076             0.698695
# 6      6  Afghanistan  AFG  1996          0.160249             0.698914
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# ...

# %%
ds=pd.read_csv("/content/clean_dataset.csv")
ds.head(7)
#this shows data about each customer and then provides if he is approved or not
# Out:
#    Gender    Age   Debt  Married  BankCustomer               Industry  \
# 0       1  30.83  0.000        1             1            Industrials
# 1       0  58.67  4.460        1             1              Materials
# 2       0  24.50  0.500        1             1              Materials
# 3       1  27.83  1.540        1             1            Industrials
# 4       1  20.17  5.625        1             1            Industrials
# 5       1  32.08  4.000        1             1  CommunicationServices
# 6       1  33.17  1.040        1             1              Transport
#
#   Ethnicity  YearsEmployed  PriorDefault  Employed  CreditScore  \
# 0     White           1.25             1         1            1
# 1     Black           3.04             1         1            6
# 2     Black           1.50             1         0            0
# 3     White           3.75             1         1            5
# 4     White           1.71             1         0            0
# ...

# %%
#excercise 3
#in "time americans spend sleeping" the quantitative data are: average hours of sleeping, standards error, year and index cause all of them have numerical values
# the Qualitative columns are:period, type of days, age group, sex, and activity cause all of them either have catogeries or labels or discription

#in "mental health depression disorder" the quantitative data are: year, Schizophrenia, Bipolar disorder, Eating disorders, Anxiety disorders, Drug use disorders, Depression, Alcohol use disorders are all measurable quantities and averages.
# the Qualitative data are: the entity and code: cause they are regions

#in "Credit Card Approvals" the quantitative data are: age, credit score,debt , years employed and income
#the Qualitative data are: gender, married, bank customer, industry, ethnicity, priordefault, emplyed, drivers liscence, citizen, zipcode and approved
