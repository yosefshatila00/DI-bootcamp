# %%
import pandas as pd
df=pd.read_csv('/Iris.csv')
df.head()
#the qualitative data are: "SepalLengthCm","SepalWidthCm", "PetalLengthCm", "PetalWidthCm" and "ID".
#the width and length are measurable data while the id is a unique numerical identifier for each row
#quantitative is the "species" cause they are just a category
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
mean_sepal_length = df['SepalLengthCm'].mean()
median_sepal_length = df['SepalLengthCm'].median()
mode_sepal_length = df['SepalLengthCm'].mode()
print("Mean Sepal Length:", mean_sepal_length)
print("Median Sepal Length:", median_sepal_length)
print("Mode Sepal Length:", mode_sepal_length)
mean_sepal_width = df['SepalWidthCm'].mean()
import matplotlib.pyplot as plt
plt.hist(df['SepalLengthCm'], bins=20) # Plot histogram of SepalLengthCm with 20 bins
plt.xlabel('Sepal Length (Cm)')
plt.ylabel('Frequency')
plt.title('Distribution of Sepal Length')
plt.show()
# Out:
# Mean Sepal Length: 5.843333333333334
# Median Sepal Length: 5.8
# Mode Sepal Length: 0    5.0
# Name: SepalLengthCm, dtype: float64
